# %%
import csv
import pprint

def kanagawa_div():

    Kanagawa = ["tsurumi", "kanagawa", "nishi", "naka", "yokohamaminami", "hodogaya", "isogo", "kanazawa", "kohoku", "totsuka", "konan", "asahi", "yokohamamidori", "seya", "sakae", "izumi", "aoba", "tsuduki", "kawasaki", "saiwai", "nakahara", "takatsu", "tama", "miyamae", "asou", "sagamiharamidori", "chuo", "sagamiharaminami", "yokosuka", "hiratsuka", "kamakura", "fujisawa", "odawara", "chigasaki", "zushi", "miura", "hadano", "atsugi", "yamato", "isehara", "ebina", "zama", "minamiashigara", "ayase", "hayama", "samukawa", "oiso", "ninomiya", "nakai", "oi", "matsuda", "yamakita", "kaisei", "hakone", "manazuru", "yugawara", "aikawa", "kiyokawa"]

    for i in range(len(Kanagawa)):
        with open(Kanagawa[i]+".csv",'w',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(["都道府県コード","都道府県名","市区町村コード","市区町村名","大字町丁目コード","大字町丁目名","緯度","経度","原典資料コード","大字・字・丁目区分コード"])


    with open("14_2021.csv", encoding='CP932') as f1:
        reader = csv.reader(f1)

        for line in reader:
            if (line[3] == "横浜市鶴見区"):
                with open(Kanagawa[0]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "横浜市神奈川区"):
                with open(Kanagawa[1]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "横浜市西区"):
                with open(Kanagawa[2]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "横浜市中区"):
                with open(Kanagawa[3]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "横浜市南区"):
                with open(Kanagawa[4]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "横浜市保土ケ谷区"):
                with open(Kanagawa[5]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "横浜市磯子区"):
                with open(Kanagawa[6]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "横浜市金沢区"):
                with open(Kanagawa[7]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "横浜市港北区"):
                with open(Kanagawa[8]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "横浜市戸塚区"):
                with open(Kanagawa[9]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "横浜市港南区"):
                with open(Kanagawa[10]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "横浜市旭区"):
                with open(Kanagawa[11]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "横浜市緑区"):
                with open(Kanagawa[12]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "横浜市瀬谷区"):
                with open(Kanagawa[13]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "横浜市栄区"):
                with open(Kanagawa[14]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "横浜市泉区"):
                with open(Kanagawa[15]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "横浜市青葉区"):
                with open(Kanagawa[16]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "横浜市都筑区"):
                with open(Kanagawa[17]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "川崎市川崎区"):
                with open(Kanagawa[18]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "川崎市幸区"):
                with open(Kanagawa[19]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "川崎市中原区"):
                with open(Kanagawa[20]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "川崎市高津区"):
                with open(Kanagawa[21]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "川崎市多摩区"):
                with open(Kanagawa[22]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "川崎市宮前区"):
                with open(Kanagawa[23]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "川崎市麻生区"):
                with open(Kanagawa[24]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "相模原市緑区"):
                with open(Kanagawa[25]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "相模原市中央区"):
                with open(Kanagawa[26]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "相模原市南区"):
                with open(Kanagawa[27]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "横須賀市"):
                with open(Kanagawa[28]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "平塚市"):
                with open(Kanagawa[29]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "鎌倉市"):
                with open(Kanagawa[30]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "藤沢市"):
                with open(Kanagawa[31]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "小田原市"):
                with open(Kanagawa[32]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "茅ヶ崎市"):
                with open(Kanagawa[33]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "逗子市"):
                with open(Kanagawa[34]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "三浦市"):
                with open(Kanagawa[35]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "秦野市"):
                with open(Kanagawa[36]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "厚木市"):
                with open(Kanagawa[37]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "大和市"):
                with open(Kanagawa[38]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "伊勢原市"):
                with open(Kanagawa[39]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "海老名市"):
                with open(Kanagawa[40]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "座間市"):
                with open(Kanagawa[41]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "南足柄市"):
                with open(Kanagawa[42]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "綾瀬市"):
                with open(Kanagawa[43]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "三浦郡葉山町"):
                with open(Kanagawa[44]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "高座郡寒川町"):
                with open(Kanagawa[45]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "中郡大磯町"):
                with open(Kanagawa[46]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "中郡二宮町"):
                with open(Kanagawa[47]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "足柄上郡中井町"):
                with open(Kanagawa[48]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "足柄上郡大井町"):
                with open(Kanagawa[49]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "足柄上郡松田町"):
                with open(Kanagawa[50]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "足柄上郡山北町"):
                with open(Kanagawa[51]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "足柄上郡開成町"):
                with open(Kanagawa[52]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "足柄下郡箱根町"):
                with open(Kanagawa[53]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "足柄下郡真鶴町"):
                with open(Kanagawa[54]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "足柄下郡湯河原町"):
                with open(Kanagawa[55]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "愛甲郡愛川町"):
                with open(Kanagawa[56]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            elif (line[3] == "愛甲郡清川村"):
                with open(Kanagawa[57]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)

# %%
if __name__ == "__main__":
    kanagawa_div()
