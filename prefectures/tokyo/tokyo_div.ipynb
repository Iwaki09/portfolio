# %%
def tokyo_div():

    import csv
    import pprint

    Citylist = ["chiyoda", "chuo", "minato", "shinjuku", "bunkyo", "taito", "sumida", "koto", "shinagawa", "meguro", "ota", "setagaya", "shibuya", "nakano", "suginami", "toshima", "kita", "arakawa", "itabashi", "nerima", "adachi", "katsushika", "edogawa", "hachioji", "tachikawa", "musashino", "mitaka", "ome", "fuchu", "akishima", "chofu", "machida", "koganei", "kodaira", "hino", "higashimurayama", "kokubunji", "kunitachi", "fussa", "komae", "higashiyamato", "kiyose", "higashikurume", "musashimurayama", "tama", "inagi", "hamura", "akiruno", "nishitokyo", "mizuho", "hinode", "hinohara", "okutama", "oshima", "toshima", "nijima", "kozushimamura", "miyake", "mikurajima", "hachijo", "aogashima", "ogasawara"]

    for i in range(len(Citylist)):
        with open(Citylist[i]+".csv",'w',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(["都道府県コード","都道府県名","市区町村コード","市区町村名","大字町丁目コード","大字町丁目名","緯度","経度","原典資料コード","大字・字・丁目区分コード"])


    with open("13_2021.csv", encoding='CP932') as f1:
        reader = csv.reader(f1)

        for line in reader:
            if (line[3] == "千代田区"):
                with open(Citylist[0]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "中央区"):
                with open(Citylist[1]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "港区"):
                with open(Citylist[2]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "新宿区"):
                with open(Citylist[3]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "文京区"):
                with open(Citylist[4]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "台東区"):
                with open(Citylist[5]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "墨田区"):
                with open(Citylist[6]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "江東区"):
                with open(Citylist[7]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "品川区"):
                with open(Citylist[8]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "目黒区"):
                with open(Citylist[9]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "大田区"):
                with open(Citylist[10]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "世田谷区"):
                with open(Citylist[11]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "渋谷区"):
                with open(Citylist[12]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "中野区"):
                with open(Citylist[13]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "杉並区"):
                with open(Citylist[14]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "豊島区"):
                with open(Citylist[15]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "北区"):
                with open(Citylist[16]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "荒川区"):
                with open(Citylist[17]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "板橋区"):
                with open(Citylist[18]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "練馬区"):
                with open(Citylist[19]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "足立区"):
                with open(Citylist[20]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "葛飾区"):
                with open(Citylist[21]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "江戸川区"):
                with open(Citylist[22]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "八王子市"):
                with open(Citylist[23]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "立川市"):
                with open(Citylist[24]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "武蔵野市"):
                with open(Citylist[25]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "三鷹市"):
                with open(Citylist[26]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "青梅市"):
                with open(Citylist[27]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "府中市"):
                with open(Citylist[28]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "昭島市"):
                with open(Citylist[29]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "調布市"):
                with open(Citylist[30]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "町田市"):
                with open(Citylist[31]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "小金井市"):
                with open(Citylist[32]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "小平市"):
                with open(Citylist[33]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "日野市"):
                with open(Citylist[34]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "東村山市"):
                with open(Citylist[35]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "国分寺市"):
                with open(Citylist[36]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "国立市"):
                with open(Citylist[37]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "福生市"):
                with open(Citylist[38]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "狛江市"):
                with open(Citylist[39]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "東大和市"):
                with open(Citylist[40]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "清瀬市"):
                with open(Citylist[41]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "東久留米市"):
                with open(Citylist[42]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "武蔵村山市"):
                with open(Citylist[43]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "多摩市"):
                with open(Citylist[44]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "稲城市"):
                with open(Citylist[45]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "羽村市"):
                with open(Citylist[46]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "あきる野市"):
                with open(Citylist[47]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "西東京市"):
                with open(Citylist[48]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "西多摩郡瑞穂町"):
                with open(Citylist[49]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "西多摩郡日の出町"):
                with open(Citylist[50]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "西多摩郡檜原村"):
                with open(Citylist[51]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "西多摩郡奥多摩町"):
                with open(Citylist[52]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "大島町"):
                with open(Citylist[53]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "利島村"):
                with open(Citylist[54]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "新島村"):
                with open(Citylist[55]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "神津島村"):
                with open(Citylist[56]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "三宅村"):
                with open(Citylist[57]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "御蔵島村"):
                with open(Citylist[58]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "八丈町"):
                with open(Citylist[59]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "青ヶ島村"):
                with open(Citylist[60]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)
            if (line[3] == "小笠原村"):
                with open(Citylist[61]+".csv",'a',encoding='utf-8') as f2:
                    writer = csv.writer(f2)
                    writer.writerow(line)

# %%
if __name__ == "__main__":
    tokyo_div()
