# %%
def word_search():

    import csv

    Pref = ["kanagawa", "gunma", "tochigi", "tokyo", "saitama", "aichi", "akita",
           "aomori", "chiba", "ehime", "fukui", "fukuoka", "fukushima", "gifu",
           "hiroshima", "hokkaido", "hyogo", "ibaraki", "ishikawa", "iwate",
           "kagawa", "kagoshima", "nagasaki", "yamagata", "kochi", "kumamoto", "kyoto",
           "mie", "miyagi", "miyazaki", "nagano", "nara", "niigata", "oita", "okayama", "okinawa", "osaka", "saga",
           "shiga", "shimane", "shizuoka", "tokushima", "tottori", "toyama", "wakayama", "yamaguchi", "yamanashi"]
        
    Kanagawa = ["tsurumi", "kanagawa", "nishi", "naka", "yokohamaminami", "hodogaya", "isogo", "kanazawa", "kohoku", "totsuka", "konan", "asahi", "yokohamamidori", "seya", "sakae", "izumi", "aoba", "tsuduki", "kawasaki", "saiwai", "nakahara", "takatsu", "tama", "miyamae", "asou", "sagamiharamidori", "chuo", "sagamiharaminami", "yokosuka", "hiratsuka", "kamakura", "fujisawa", "odawara", "chigasaki", "zushi", "miura", "hadano", "atsugi", "yamato", "isehara", "ebina", "zama", "minamiashigara", "ayase", "hayama", "samukawa", "oiso", "ninomiya", "nakai", "oi", "matsuda", "yamakita", "kaisei", "hakone", "manazuru", "yugawara", "aikawa", "kiyokawa"]
    Gunma = ["maebashi", "takasaki", "kiryu", "isesaki", "ota", "numata", "tatebayashi", "shibukawa", "fujioka", "tomioka", "annaka", "midori", "shinto", "yoshioka", "ueno", "kanna", "shimonita", "nanmoku", "kanra", "nakanojo", "naganohara", "tsumagoi", "kusatsu", "takayama", "higashiagatsuma", "katashina", "kawaba", "showa", "minakami", "tamamura", "itakura", "meiwa", "chiyoda", "oizumi", "ora"]
    Tochigi = ["utsunomiya", "ashikaga", "tochigi", "sano", "kanuma", "nikko", "oyama", "mooka", "otawara", "yaita", "nasushiobara", "sakura", "nasukarasuyama", "simotsuke", "kaminokawa", "mashiko", "motegi", "ichikai", "haga", "mibu", "nogi", "shioya", "takanezawa", "nasu", "nakagawa"]
    Tokyo = ["chiyoda", "chuo", "minato", "shinjuku", "bunkyo", "taito", "sumida", "koto", "shinagawa", "meguro", "ota", "setagaya", "shibuya", "nakano", "suginami", "toshima", "kita", "arakawa", "itabashi", "nerima", "adachi", "katsushika", "edogawa", "hachioji", "tachikawa", "musashino", "mitaka", "ome", "fuchu", "akishima", "chofu", "machida", "koganei", "kodaira", "hino", "higashimurayama", "kokubunji", "kunitachi", "fussa", "komae", "higashiyamato", "kiyose", "higashikurume", "musashimurayama", "tama", "inagi", "hamura", "akiruno", "nishitokyo", "mizuho", "hinode", "hinohara", "okutama", "oshima", "toshima", "nijima", "kozushimamura", "miyake", "mikurajima", "hachijo", "aogashima", "ogasawara"]
    Toyama = ["toyama", "takaoka", "uozu", "himi", "namerikawa", "kurobe", "tonami", "oyabe", "nanto", "izumi"]
    Wakayama = ["wakayama", "kainan", "hashimoto", "arida", "gobo", "tanabe", "shingu", "kinokawa", "iwade"]
    Yamaguchi = ["shimonoseki", "ube", "yamaguchi", "hagi", "hofu", "kudamatsu", "iwakuni", "hikari", "nagato", "yanai", "mine", "shunan", "sanyoonoda"]
    Yamanashi = ["kofu", "fujiyoshida", "tsuru", "yamanashi", "otsuki", "nirasaki", "minamiarupusu", "hokuto", "kai", "fuefuki", "uenohara", "koshu", "chuo"]


    All_city_list = []
    
    
    All_city_list.append(Kanagawa)
    All_city_list.append(Gunma)
    All_city_list.append(Tochigi)
    All_city_list.append(Tokyo)
    All_city_list.append(Saitama)
    All_city_list.append(Aichi)
    All_city_list.append(Akita)
    All_city_list.append(Aomori)
    All_city_list.append(Chiba)
    All_city_list.append(Ehime)
    All_city_list.append(Fukui)
    All_city_list.append(Fukuoka)
    All_city_list.append(Fukushima)
    All_city_list.append(Gifu)
    All_city_list.append(Hiroshima)
    All_city_list.append(Hokkaido)
    All_city_list.append(Hyogo)
    All_city_list.append(Ibaraki)
    All_city_list.append(Ishikawa)
    All_city_list.append(Iwate)
    All_city_list.append(Kagawa)
    All_city_list.append(Kagoshima)
    All_city_list.append(Nagasaki)
    All_city_list.append(Yamagata)
    All_city_list.append(Kochi)
    All_city_list.append(Kumamoto)
    All_city_list.append(Kyoto)
    All_city_list.append(Mie)
    All_city_list.append(Miyagi)
    All_city_list.append(Miyazaki)
    All_city_list.append(Nagano)
    All_city_list.append(Nara)
    All_city_list.append(Nigata)
    All_city_list.append(Oita)
    All_city_list.append(Okayama)
    All_city_list.append(Okinawa)
    All_city_list.append(Osaka)
    All_city_list.append(Saga)
    All_city_list.append(Shiga)
    All_city_list.append(Shimane)
    All_city_list.append(Shizuoka)
    All_city_list.append(Tokushima)
    All_city_list.append(Tottori)
    All_city_list.append(Toyama)
    All_city_list.append(Wakayama)
    All_city_list.append(Yamaguchi)
    All_city_list.append(Yamanashi)
             
    
    
    
    freq_word_list = []
    
    click_ranking = []
    click_ranking_sub = []
             
    for i in range(47):
        
        print("-----------------")
        print(Pref[i])
        
        pref_dict = {}

        for city in All_city_list[i]:
            
            print(city)

            town_list = []

            cityname = city

            with open("./prefectures/"+Pref[i]+"/"+cityname+"_processed.csv", encoding='utf-8') as f1:
                reader = csv.reader(f1)

                second_flag = 0
                for line in reader:
                    town_list.append(line[0])
                    if (second_flag < 2):
                         # 県名と市区町村名が漢字で入っている
                        pref_name_ja, city_name_ja = line[0], line[1]
                        second_flag += 1

            town_list.pop(0)
            town_list.pop(0)

        #     漢字の出現回数判定。初登場のものは辞書に新しく入れて、２回目以降はカウントを＋１する。

            dict = {}

            for town in town_list:
                char_list = list(town)
                for char in char_list:
                    if char in dict.keys():
                        dict[char] += 1
                    else:
                        dict[char] = 1
                        
            for town in town_list:
                char_list = list(town)
                for char in char_list:
                    if char in pref_dict.keys():
                        pref_dict[char] += 1
                    else:
                        pref_dict[char] = 1

        #     データの書き出し
        
            letter_sum = 0

            with open("./prefectures/"+Pref[i]+"/"+cityname+"_res.csv",'w',encoding='utf-8') as f2:
                writer = csv.writer(f2)
                writer.writerow(["let", "num"])
                for k, v in dict.items():
                    writer.writerow([k, v])
                    if (k not in click_ranking_sub):
                        click_ranking_sub.append(k)
                        click_ranking.append([k, v, Pref[i], cityname, pref_name_ja, city_name_ja])
                    else:
                        n = click_ranking_sub.index(k)
                        if (click_ranking[n][1] < v):
                            click_ranking[n] = [k, v, Pref[i], cityname, pref_name_ja, city_name_ja]
                    letter_sum += v
#             print(click_ranking)

            dict2 = sorted(dict.items(), key=lambda x:x[1], reverse = True)
            tmp_list = []
            tmp_list.append(Pref[i])
            tmp_list.append(cityname)
            tmp_list.append(pref_name_ja)
            tmp_list.append(city_name_ja)

            for k in range(min(10, len(dict2))):
                tmp_list.append(dict2[k][0])
                tmp_list.append(dict2[k][1] / letter_sum)

            freq_word_list.append(tmp_list)
            
        with open("./prefectures/"+Pref[i]+"/"+Pref[i]+"_for_bubble.csv",'w',encoding='utf-8') as f2:
            writer = csv.writer(f2)
            writer.writerow(["let", "num"])
            for k, v in pref_dict.items():
                if (v > 10):
                    writer.writerow([k, v])
                    letter_sum += v

    with open("frequent_word.csv",'w',encoding='utf-8') as f2:
        writer = csv.writer(f2)
        writer.writerow(["pref_en", "cityname_en", "pref_ja", "cityname_ja", "rank1_let", "rank1_prob", "rank2_let", "rank2_prob", "rank3_let", "rank3_prob", "rank4_let", "rank4_prob", "rank5_let", "rank5_prob", "rank6_let", "rank6_prob", "rank7_let", "rank7_prob", "rank8_let", "rank8_prob", "rank9_let", "rank9_prob", "rank10_let", "rank10_prob"])
        for line in freq_word_list:
            writer.writerow(line)
            
    with open("kanji_rank.csv",'w',encoding='utf-8') as f2:
        writer = csv.writer(f2)
        writer.writerow(["let", "num", "pref_en", "cityname_en", "pref_ja", "cityname_ja"])
        for line in click_ranking:
            writer.writerow(line)

# %%
if __name__ == "__main__":
    word_search()
# Out:
# -----------------
# kanagawa
# tsurumi
# kanagawa
# nishi
# naka
# yokohamaminami
# hodogaya
# isogo
# kanazawa
# kohoku
# totsuka
# konan
# asahi
# yokohamamidori
# seya
# sakae
# izumi
# aoba
# tsuduki
# kawasaki
# saiwai
# nakahara
# takatsu
# tama
# miyamae
# asou
# sagamiharamidori
# chuo
# sagamiharaminami
# yokosuka
# hiratsuka
# kamakura
# fujisawa
# odawara
# chigasaki
# zushi
# miura
# hadano
# atsugi
# yamato
# isehara
# ebina
# zama
# minamiashigara
# ayase
# hayama
# samukawa
# oiso
# ninomiya
# nakai
# oi
# matsuda
# yamakita
# kaisei
# hakone
# manazuru
# yugawara
# aikawa
# kiyokawa
# -----------------
# gunma
# maebashi
# takasaki
# kiryu
# isesaki
# ota
# numata
# tatebayashi
# shibukawa
# fujioka
# tomioka
# annaka
# midori
# shinto
# yoshioka
# ueno
# kanna
# shimonita
# nanmoku
# kanra
# nakanojo
# naganohara
# tsumagoi
# kusatsu
# takayama
# higashiagatsuma
# katashina
# kawaba
# showa
# minakami
# tamamura
# itakura
# meiwa
# chiyoda
# oizumi
# ora
# ...
